# %% [markdown]
# <a href="https://colab.research.google.com/github/Moi2204/Minh/blob/main/BTAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
m=folium.Map(location=[10.770346152188406, 106.67210855734689], zoom_start=12)
folium.Marker([10.763351076839502, 106.66777125996533],popup='UEH-B',tooltip='click here').add_to(m)
folium.Marker([10.77430019206919, 106.6659590902487],popup='Bệnh viện ND115',tooltip='hospital').add_to(m)
folium.Marker([10.782343736975935, 106.67730818939222],popup='Ga SG',tooltip='station').add_to(m)
folium.Marker([10.772385822174895, 106.67330286738002],popup='VN Quốc Tự',tooltip='click here').add_to(m)
folium.Marker([10.772710383607587, 106.66921475424176],popup='Vạn Hạnh Mall',tooltip='Click here').add_to(m)
folium.Marker([10.773332235520861, 106.67761711916535],popup="UEH-C",Tooltip='click here').add_to(m)
folium.Marker([10.765632253423707, 106.67707399617717],popup="chợ Hồ Thị Kỷ",Tooltip='click here').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a37be67eb9e3c5913b86e66b18713ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a37be67eb9e3c5913b86e66b18713ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a37be67eb9e3c5913b86e66b18713ff = L.map(
#                 &quot;map_9a37be67eb9e3c5913b86e66b18713ff&quot;,
#                 {
#                     center: [10.770346152188406, 106.67210855734689],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19362a3f51271e6431575bc0fe216754 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_19362a3f51271e6431575bc0fe216754.addTo(map_9a37be67eb9e3c5913b86e66b18713ff);
#
#
#             var marker_ca803f5b06641b60ae920a6cb19b4108 = L.marker(
#                 [10.763351076839502, 106.66777125996533],
#                 {
# }
#             ).addTo(map_9a37be67eb9e3c5913b86e66b18713ff);
#
#
#         var popup_bccbd125229f860ab92353365e2966d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf720130507a03beb91a9f78cec4856f = $(`&lt;div id=&quot;html_cf720130507a03beb91a9f78cec4856f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UEH-B&lt;/div&gt;`)[0];
#                 popup_bccbd125229f860ab92353365e2966d4.setContent(html_cf720130507a03beb91a9f78cec4856f);
#
#
#
#         marker_ca803f5b06641b60ae920a6cb19b4108.bindPopup(popup_bccbd125229f860ab92353365e2966d4)
#         ;
#
#
#
#
#             marker_ca803f5b06641b60ae920a6cb19b4108.bindTooltip(
#                 `&lt;div&gt;
#                      click here
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_8009cd14b05af6e1dcb2f131e010eecf = L.marker(
#                 [10.77430019206919, 106.6659590902487],
#                 {
# }
#             ).addTo(map_9a37be67eb9e3c5913b86e66b18713ff);
#
#
#         var popup_74b9c5b0bf31dacd4e0082d66e8f1182 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78e2ad822bb966c77911a27ed9231d02 = $(`&lt;div id=&quot;html_78e2ad822bb966c77911a27ed9231d02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bệnh viện ND115&lt;/div&gt;`)[0];
#                 popup_74b9c5b0bf31dacd4e0082d66e8f1182.setContent(html_78e2ad822bb966c77911a27ed9231d02);
#
#
#
#         marker_8009cd14b05af6e1dcb2f131e010eecf.bindPopup(popup_74b9c5b0bf31dacd4e0082d66e8f1182)
#         ;
#
#
#
#
#             marker_8009cd14b05af6e1dcb2f131e010eecf.bindTooltip(
#                 `&lt;div&gt;
#                      hospital
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_546ee53a99c779293fe5a16d1db721da = L.marker(
#                 [10.782343736975935, 106.67730818939222],
#                 {
# }
#             ).addTo(map_9a37be67eb9e3c5913b86e66b18713ff);
#
#
#         var popup_ae07a12029a21f63387155b089d8b600 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f465866ea1dab84c0cb9dc24824c09f = $(`&lt;div id=&quot;html_1f465866ea1dab84c0cb9dc24824c09f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ga SG&lt;/div&gt;`)[0];
#                 popup_ae07a12029a21f63387155b089d8b600.setContent(html_1f465866ea1dab84c0cb9dc24824c09f);
#
#
#
#         marker_546ee53a99c779293fe5a16d1db721da.bindPopup(popup_ae07a12029a21f63387155b089d8b600)
#         ;
#
#
#
#
#             marker_546ee53a99c779293fe5a16d1db721da.bindTooltip(
#                 `&lt;div&gt;
#                      station
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_dfa252e7c4174b91545351df3b2a7311 = L.marker(
#                 [10.772385822174895, 106.67330286738002],
#                 {
# }
#             ).addTo(map_9a37be67eb9e3c5913b86e66b18713ff);
#
#
#         var popup_f33f7390289623a4c03d78bcf0d5d02c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52551ae882e4fcd09e84ff3ca2e6f0e1 = $(`&lt;div id=&quot;html_52551ae882e4fcd09e84ff3ca2e6f0e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VN Quốc Tự&lt;/div&gt;`)[0];
#                 popup_f33f7390289623a4c03d78bcf0d5d02c.setContent(html_52551ae882e4fcd09e84ff3ca2e6f0e1);
#
#
#
#         marker_dfa252e7c4174b91545351df3b2a

# %%
import folium
from geopy.geocoders import Nominatim
from geopy import Location
from geopy.distance import distance
geolocator=Nominatim(user_agent="my-geocoder")
m=folium.Map([10.78228616820709, 106.67740465561394])
folium.Marker([10.78228616820709, 106.67740465561394],popup="Ga Sài gòn",tooltip='Trung tâm').add_to(m)
Name=['Nhà Thờ Đức Bà,Ho Chi Minh City',
     'Landmark 81,Ho Chi Minh City',
     'Chợ Bến Thành,Ho Chi Minh City',
     'Vinpearl Resort Nha Trang, Khanh Hoa',
     'Bến Xe Miền Đông Mới,Ho Chi Minh City',
     'Ga Nha Trang, Khanh Hoa',
     'Thánh Địa Mỹ Sơn,Da Nang City',
     'Hòn Chồng, Khánh Hoà',
     'Nha Trang Beach, Khanh Hoa',
     'Tram Huong Tower, Khanh Hoa']
for i in Name:
  Location=geolocator.geocode(i)
  print(f'Địa điểm là {i}')
  print(f'Tọa độ là: {Location.latitude,Location.longitude}')
gaSG=[10.78228616820709, 106.67740465561394]
Kc=[('Nhà Thờ Đức Bà',(10.7792374, 106.6991514)),
             ('Landmark 81',(10.7950845, 106.7219139)),
             ('Chợ Bến Thành',(10.7725301, 106.6980365)),
             ('Hòn chồng',(12.273680396835324, 109.20636252665257)),
             ('Bến Xe Miền Đông Mới',(10.8795958, 106.8159644)),
             ('Ga Nha Trang',(12.248479464068174, 109.18419981960706)),
             ('Thánh Địa Mỹ Sơn',(15.7655202, 108.1234531)),
             ('Tháp Trầm Hương',(12.241257714175397, 109.19622861005142)),
             ('Vinpearl Resort Nha Trang',(12.223000797491348, 109.24668436946776)),
             ('Nha Trang Beach',(12.237343123034675, 109.19786727942078))]
for name,coord in Kc:
  ds=distance(gaSG,coord).km
  print(f'{name} cách {ds:.2f}km từ GA SG')
m
# Out:
# Địa điểm là Nhà Thờ Đức Bà,Ho Chi Minh City
# Tọa độ là: (10.7792374, 106.6991514)
# Địa điểm là Landmark 81,Ho Chi Minh City
# Tọa độ là: (10.795827, 106.7225902)
# Địa điểm là Chợ Bến Thành,Ho Chi Minh City
# Tọa độ là: (10.7725301, 106.6980365)
# Địa điểm là Vinpearl Resort Nha Trang, Khanh Hoa
# Tọa độ là: (12.2245328, 109.2396832)
# Địa điểm là Bến Xe Miền Đông Mới,Ho Chi Minh City
# Tọa độ là: (10.8795958, 106.8159644)
# Địa điểm là Ga Nha Trang, Khanh Hoa
# Tọa độ là: (12.2348769, 109.1941443)
# Địa điểm là Thánh Địa Mỹ Sơn,Da Nang City
# Tọa độ là: (15.7655202, 108.1234531)
# Địa điểm là Hòn Chồng, Khánh Hoà
# Tọa độ là: (12.2728399, 109.2065606)
# Địa điểm là Nha Trang Beach, Khanh Hoa
# Tọa độ là: (12.2363052, 109.1979116)
# Địa điểm là Tram Huong Tower, Khanh Hoa
# Tọa độ là: (12.2405391, 109.1969378)
# Nhà Thờ Đức Bà cách 2.40km từ GA SG
# Landmark 81 cách 5.07km từ GA SG
# Chợ Bến Thành cách 2.50km từ GA SG
# Hòn chồng cách 321.44km từ GA SG
# Bến Xe Miền Đông Mới cách 18.59km từ GA SG
# Ga Nha Trang cách 317.94km từ GA SG
# Thánh Địa Mỹ Sơn cách 573.13km từ GA SG
# Tháp Trầm Hương cách 318.67km từ GA SG
# Vinpearl Resort Nha Trang cách 322.43km từ GA SG
# Nha Trang Beach cách 318.61km từ GA SG
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_824d1510236436b18ba0120d2d6fae83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_824d1510236436b18ba0120d2d6fae83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_824d1510236436b18ba0120d2d6fae83 = L.map(
#                 &quot;map_824d1510236436b18ba0120d2d6fae83&quot;,
#                 {
#                     center: [10.78228616820709, 106.67740465561394],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f37210315fd5ef8db1956d3bab9ba24 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f37210315fd5ef8db1956d3bab9ba24.addTo(map_824d1510236436b18ba0120d2d6fae83);
#
#
#             var marker_be4ea41cfcc24c475cb0c01e458e157f = L.marker(
#                 [10.78228616820709, 106.67740465561394],
#                 {
# }
#             ).addTo(map_824d1510236436b18ba0120d2d6fae83);
#
#
#         var popup_a1ee2be67f5618688da74c61b2d6c85a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_368e90644673f0b55eac59640eb68b67 = $(`&lt;div id=&quot;html_368e90644673f0b55eac59640eb68b67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ga Sài gòn&lt;/div&gt;`)[0];
#                 popup_a1ee2be67f5618688da74c61b2d6c85a.setContent(html_368e90644673f0b55eac59640eb68b67);
#
#
#
#         marker_be4ea41cfcc24c475cb0c01e458e157f.bindPopup(popup_a1ee2be67f5618688da74c61b2d6c85a)
#         ;
#
#
#
#
#             marker_be4ea41cfcc24c475cb0c01e458e157f.bindTooltip(
#                 `&lt;div&gt;
#                      Trung tâm
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.plugins import HeatMap
m=folium.Map([10.776732124904017, 106.68366338358513],zoom_start=13)
folium.Marker([10.757991842709464, 106.65950266604241],popup='BV Chợ Rẫy',tooltip='click here').add_to(m)
folium.Marker([10.79530159071321, 106.72212818267303],popup='Tòa nhà cao nhất VN',tooltip='click here').add_to(m)
heat_data=[(10.757991842709464, 106.65950266604241),(10.79530159071321, 106.72212818267303)]
HeatMap(heat_data).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fdcf64bbdf28784c4cdc66a88f3f58d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fdcf64bbdf28784c4cdc66a88f3f58d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fdcf64bbdf28784c4cdc66a88f3f58d = L.map(
#                 &quot;map_5fdcf64bbdf28784c4cdc66a88f3f58d&quot;,
#                 {
#                     center: [10.776732124904017, 106.68366338358513],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28d8e6a4e0b428d87bd340753e6ecd4c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_28d8e6a4e0b428d87bd340753e6ecd4c.addTo(map_5fdcf64bbdf28784c4cdc66a88f3f58d);
#
#
#             var marker_e715910674e6b6027283cc662a722280 = L.marker(
#                 [10.757991842709464, 106.65950266604241],
#                 {
# }
#             ).addTo(map_5fdcf64bbdf28784c4cdc66a88f3f58d);
#
#
#         var popup_6aeed5a2a8c42ae3ef86de82f61c3446 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af0d911b228bf09f93a20791153822ab = $(`&lt;div id=&quot;html_af0d911b228bf09f93a20791153822ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BV Chợ Rẫy&lt;/div&gt;`)[0];
#                 popup_6aeed5a2a8c42ae3ef86de82f61c3446.setContent(html_af0d911b228bf09f93a20791153822ab);
#
#
#
#         marker_e715910674e6b6027283cc662a722280.bindPopup(popup_6aeed5a2a8c42ae3ef86de82f61c3446)
#         ;
#
#
#
#
#             marker_e715910674e6b6027283cc662a722280.bindTooltip(
#                 `&lt;div&gt;
#                      click here
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_799f4807a00d5bb76fe15dda1b40cd49 = L.marker(
#                 [10.79530159071321, 106.72212818267303],
#                 {
# }
#             ).addTo(map_5fdcf64bbdf28784c4cdc66a88f3f58d);
#
#
#         var popup_8c4dfa15b125d8ce50224467692058b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a1d4eb7e3bbc3de07b4ef933e1ae2fb = $(`&lt;div id=&quot;html_6a1d4eb7e3bbc3de07b4ef933e1ae2fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tòa nhà cao nhất VN&lt;/div&gt;`)[0];
#                 popup_8c4dfa15b125d8ce50224467692058b0.setContent(html_6a1d4eb7e3bbc3de07b4ef933e1ae2fb);
#
#
#
#         marker_799f4807a00d5bb76fe15dda1b40cd49.bindPopup(popup_8c4dfa15b125d8ce50224467692058b0)
#         ;
#
#
#
#
#             marker_799f4807a00d5bb76fe15dda1b40cd49.bindTooltip(
#                 `&lt;div&gt;
#                      click here
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var heat_map_9a6881cc37e889c06a3fe9ee6ba86271 = L.heatLayer(
#                 [[10.757991842709464, 106.65950266604241], [10.79530159071321, 106.72212818267303]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_9a6881cc37e889c06a3fe9ee6ba86271.addTo(map_5fdcf64bbdf28784c4cdc66a88f3f58d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import numpy as np
url = "https://raw.githubusercontent.com/TungTh/tungth.github.io/master/data/vn-provinces.json"
try:
    map_data = gpd.read_file(url)
    col_name = 'name' if 'name' in map_data.columns else map_data.columns[1]
except Exception as e:
    polygons = []
    names = []
    for i in range(4):
        for j in range(4):
            polygons.append(Polygon([(i, j), (i+1, j), (i+1, j+1), (i, j+1)]))
            names.append(f"Khu vực {i*4 + j + 1}")
    map_data = gpd.GeoDataFrame({'name': names, 'geometry': polygons})
    col_name = 'name'
tinh_list = map_data[col_name].dropna().unique()
df_business = pd.DataFrame({
    col_name: tinh_list,
    'Doanh_Thu': np.random.randint(100, 1000, size=len(tinh_list))
})
merged = map_data.merge(df_business, on=col_name, how="left")
fig, ax = plt.subplots(1, 1, figsize=(10, 12))
merged.plot(
    column='Doanh_Thu',
    ax=ax,
    legend=True,
    cmap='YlGnBu',
    edgecolor='black',
    linewidth=0.5,
    legend_kwds={'label': "Doanh thu (Tỷ đồng)", 'shrink': 0.5}
)

plt.title('23.4: BẢN ĐỒ CHOROPLETH PHÂN BỔ DOANH THU', fontsize=16, fontweight='bold')
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
import folium
import pandas as pd
import numpy as np
from geopy.distance import geodesic

center_lat, center_lon = 12.2451, 109.1943
center_location = (center_lat, center_lon)
np.random.seed(42)
num_customers = 150
latitudes = center_lat + np.random.uniform(-0.1, 0.1, num_customers)
longitudes = center_lon + np.random.uniform(-0.1, 0.1, num_customers)
customers = pd.DataFrame({
    'CustomerID': range(1, num_customers + 1),
    'Lat': latitudes,
    'Lon': longitudes
})
def calculate_zone(row):
    dist_km = geodesic(center_location, (row['Lat'], row['Lon'])).kilometers
    if dist_km <= 3:
        return 'Vùng 1 (0-3km)', dist_km, 'green'
    elif dist_km <= 5:
        return 'Vùng 2 (3-5km)', dist_km, 'orange'
    elif dist_km <= 10:
        return 'Vùng 3 (5-10km)', dist_km, 'blue'
    else:
        return 'Ngoài vùng (>10km)', dist_km, 'red'

customers[['Zone', 'Distance_km', 'Color']] = customers.apply(
    lambda row: pd.Series(calculate_zone(row)), axis=1
)
m = folium.Map(location=[center_lat, center_lon], zoom_start=12)
folium.Marker(
    location=[center_lat, center_lon],
    popup="<b>KHO HÀNG KHÁNH HÒA</b>",
    icon=folium.Icon(color="darkred", icon="home", prefix='fa')
).add_to(m)
radii_config = {
    3000: {'color': 'green', 'name': '3 km'},
    5000: {'color': 'orange', 'name': '5 km'},
    10000: {'color': 'blue', 'name': '10 km'}
}
for radius_m, config in radii_config.items():
    folium.Circle(
        location=[center_lat, center_lon],
        radius=radius_m,
        color=config['color'],
        weight=2,
        fill=True,
        fill_opacity=0.1,
        popup=f"Bán kính phục vụ: {config['name']}"
    ).add_to(m)
for _, row in customers.iterrows():
    folium.CircleMarker(
        location=[row['Lat'], row['Lon']],
        radius=4,
        color=row['Color'],
        fill=True,
        fill_opacity=0.7,
        popup=f"KH {row['CustomerID']}<br>Cách kho: {row['Distance_km']:.2f} km"
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7ffa5e518597943d33b948d8d92a976 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7ffa5e518597943d33b948d8d92a976&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7ffa5e518597943d33b948d8d92a976 = L.map(
#                 &quot;map_c7ffa5e518597943d33b948d8d92a976&quot;,
#                 {
#                     center: [12.2451, 109.1943],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_221650653b1073671009b74a62d038d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_221650653b1073671009b74a62d038d0.addTo(map_c7ffa5e518597943d33b948d8d92a976);
#
#
#             var marker_166829b7d32b15e9b00ea8e977735855 = L.marker(
#                 [12.2451, 109.1943],
#                 {
# }
#             ).addTo(map_c7ffa5e518597943d33b948d8d92a976);
#
#
#             var icon_9bae01a317b00f8881a1cc3a6b173a72 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkred&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fe446e552714835a1d76443b73766b68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae65bf06a3f351f10779bb5694026aba = $(`&lt;div id=&quot;html_ae65bf06a3f351f10779bb5694026aba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;KHO HÀNG KHÁNH HÒA&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_fe446e552714835a1d76443b73766b68.setContent(html_ae65bf06a3f351f10779bb5694026aba);
#
#
#
#         marker_166829b7d32b15e9b00ea8e977735855.bindPopup(popup_fe446e552714835a1d76443b73766b68)
#         ;
#
#
#
#
#                 marker_166829b7d32b15e9b00ea8e977735855.setIcon(icon_9bae01a317b00f8881a1cc3a6b173a72);
#
#
#             var circle_429c63c758f940e032b54c9896e2dbec = L.circle(
#                 [12.2451, 109.1943],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c7ffa5e518597943d33b948d8d92a976);
#
#
#         var popup_e970356ff95f37ae6ca57933c45b679f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_009b16febab83cba2d537c42cd505fe7 = $(`&lt;div id=&quot;html_009b16febab83cba2d537c42cd505fe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bán kính phục vụ: 3 km&lt;/div&gt;`)[0];
#                 popup_e970356ff95f37ae6ca57933c45b679f.setContent(html_009b16febab83cba2d537c42cd505fe7);
#
#
#
#         circle_429c63c758f940e032b54c9896e2dbec.bindPopup(popup_e970356ff95f37ae6ca57933c45b679f)
#         ;
#
#
#
#
#             var circle_a3b85b8d79aaa31c32a2a54d5e89624d = L.circle(
#                 [12.2451, 109.1943],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c7ffa5e518597943d33b948d8d92a976);
#
#
#         var popup_cb8ce178c6eaec7bff179966d1139e69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dde5ed6cf317d9ac900795de5c8c30f3 = $(`&lt;div id=&quot;html_dde5ed6cf317d9ac900795de5c8c30f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bán kính phục vụ: 5 km&lt;/div&gt;`)[0];
#                 popup_cb8ce178c6eaec7bff179966d1139e69.setContent(html_dde5ed6cf317d9ac900795de5c8c30f3);
#
#
#
#         circle_a3b85b8d79aaa31c32a2a54d5e89624d.bindPopup(popup_cb8ce178c6eaec7bff179966d1139e69)
#         ;
#
#
#
#
#             var circle_9b967ac862c55e8fee178c5dc464c48f = L.circle(

# %%
# !pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-2.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.3)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.30 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (26.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->osmnx) (1.17.0)
# Downloading osmnx-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.1.0

# %%
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt
place_name = "Dien Khanh District, Khanh Hoa, Vietnam"
G = ox.graph_from_place(place_name, network_type='drive')
fig, ax = ox.plot_graph(G, node_size=1, node_color='w', edge_color='gray', edge_linewidth=0.5)

nodes, edges = ox.graph_to_gdfs(G)
print(f"Số lượng nút: {len(nodes)}")
print(f"Số lượng đường: {len(edges)}")
area = 336.2
network_density = len(edges) / area
print(f"Mật độ mạng lưới: {network_density:.2f} đoạn đường/km2")
avg_edge_length = edges['length'].mean()
print(f"Chiều dài trung bình đoạn đường: {avg_edge_length:.2f} mét")

print("\nVai trò của dữ liệu mạng lưới giao thông trong AI đô thị (tại Diên Khánh):")
print("1. Tối ưu hóa lộ trình: AI sử dụng đồ thị này để tìm đường ngắn nhất kết nối các xã với thị trấn.")
print("2. Dự báo tắc nghẽn: Phân tích lưu lượng trên Quốc lộ 1A và các tuyến cửa ngõ phía Tây Nha Trang.")
print("3. Quy hoạch đô thị: Xác định các nút giao tại khu vực Thành cổ cần bảo tồn hoặc điều chỉnh hạ tầng.")
print("4. Giao thông công cộng: Thiết lập lộ trình xe buýt liên huyện tối ưu dựa trên phân bổ dân cư và mạng lưới đường.")
# Out:
# Số lượng nút: 4032
# Số lượng đường: 9670
# Mật độ mạng lưới: 28.76 đoạn đường/km2
# Chiều dài trung bình đoạn đường: 138.56 mét
#
# Vai trò của dữ liệu mạng lưới giao thông trong AI đô thị (tại Diên Khánh):
# 1. Tối ưu hóa lộ trình: AI sử dụng đồ thị này để tìm đường ngắn nhất kết nối các xã với thị trấn.
# 2. Dự báo tắc nghẽn: Phân tích lưu lượng trên Quốc lộ 1A và các tuyến cửa ngõ phía Tây Nha Trang.
# 3. Quy hoạch đô thị: Xác định các nút giao tại khu vực Thành cổ cần bảo tồn hoặc điều chỉnh hạ tầng.
# 4. Giao thông công cộng: Thiết lập lộ trình xe buýt liên huyện tối ưu dựa trên phân bổ dân cư và mạng lưới đường.

# %%
import osmnx as ox
import networkx as nx
import random
import matplotlib.pyplot as plt

place_name = "Dien Khanh District, Khanh Hoa, Vietnam"
G = ox.graph_from_place(place_name, network_type='drive')
nodes = list(G.nodes())
start_node = random.choice(nodes)
end_node = random.choice(nodes)
A = nx.shortest_path(G, start_node, end_node, weight='length')
B = nx.astar_path(G, start_node, end_node, weight='length')

print(f"Đường đi A: {A}")
print(f"Đường đi B: {B}")
fig, ax = ox.plot_graph_routes(
    G,
    routes=[A, B],
    route_colors=['red', 'blue'],
    route_linewidths=[6, 2],
    node_size=0
)
print(f"Độ dài A: {nx.path_weight(G, A, weight='length'):.2f} mét")
print(f"Độ dài B: {nx.path_weight(G, B, weight='length'):.2f} mét")

print("\nPhân tích (Bối cảnh Diên Khánh):")
print("- Dijkstra: Quét mọi hướng để tìm đường ngắn nhất, hiệu quả cho các mạng lưới đường phức tạp quanh Thành cổ.")
print("- A*: Định hướng tìm kiếm về phía đích, giúp tiết kiệm tài nguyên tính toán khi xử lý các tuyến đường dài nối các xã.")
# Out:
# Đường đi A: [3856117246, 3872646479, 7218007295, 3872652664, 3872653887, 1656399802, 1656399894, 3856109247, 3856106918, 7199782219, 3874354270, 7199782215, 7199782213, 446356126, 7199762861, 7199762857, 7199762859, 3874351200, 3889873972, 3874352264, 3872658497, 2288750697, 2035233894, 7199762863, 7189333846, 7283884662, 7189333861, 7189333826, 7189333813, 7189333808, 7189333812, 446356152, 5309912673, 7241474707, 7189318062, 7189318057, 5309912671, 5309912906, 7189318053, 7189318050, 446356168, 7186513981, 7186513978, 446356170, 7186513969, 446356174, 7282017608]
# Đường đi B: [3856117246, 3872646479, 7218007295, 3872652664, 3872653887, 1656399802, 1656399894, 3856109247, 3856106918, 7199782219, 3874354270, 7199782215, 7199782213, 446356126, 7199762861, 7199762857, 7199762859, 3874351200, 3889873972, 3874352264, 3872658497, 2288750697, 2035233894, 7199762863, 7189333846, 7283884662, 7189333861, 7189333826, 7189333813, 7189333808, 7189333812, 446356152, 5309912673, 7241474707, 7189318062, 7189318057, 5309912671, 5309912906, 7189318053, 7189318050, 446356168, 7186513981, 7186513978, 446356170, 7186513969, 446356174, 7282017608]
# Độ dài A: 5711.74 mét
# Độ dài B: 5711.74 mét
#
# Phân tích (Bối cảnh Diên Khánh):
# - Dijkstra: Quét mọi hướng để tìm đường ngắn nhất, hiệu quả cho các mạng lưới đường phức tạp quanh Thành cổ.
# - A*: Định hướng tìm kiếm về phía đích, giúp tiết kiệm tài nguyên tính toán khi xử lý các tuyến đường dài nối các xã.

# %%
import folium
import osmnx as ox
import networkx as nx
center = [10.7769, 106.7009]
customer_loc = [10.7700, 106.7100]
car_loc = [10.7800, 106.6900]
print("Đang tải dữ liệu bản đồ...")
G = ox.graph_from_point(tuple(center), dist=3000, network_type='drive')
orig_node = ox.distance.nearest_nodes(G, X=car_loc[1], Y=car_loc[0])
dest_node = ox.distance.nearest_nodes(G, X=customer_loc[1], Y=customer_loc[0])
route = nx.shortest_path(G, orig_node, dest_node, weight='length')
route_length = nx.shortest_path_length(G, orig_node, dest_node, weight='length')
print(f"Khoảng cách đường đi thực tế: {route_length:.2f} mét")
route_coords = []
for node in route:
    lat = G.nodes[node]['y']
    lon = G.nodes[node]['x']
    route_coords.append([lat, lon])
m = folium.Map(location=center, zoom_start=14)
folium.Marker(customer_loc, icon=folium.Icon(color='blue', icon='user'), popup="Khách hàng").add_to(m)
folium.Marker(car_loc, icon=folium.Icon(color='red', icon='car'), popup="Xe công nghệ").add_to(m)
folium.PolyLine(route_coords, color="red", weight=4, opacity=0.8, popup=f"{route_length:.2f} mét").add_to(m)
m
# Out:
# Đang tải dữ liệu bản đồ...
# Khoảng cách đường đi thực tế: 5166.32 mét
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9db21f59cc231ba483e94c1e17adf850 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9db21f59cc231ba483e94c1e17adf850&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9db21f59cc231ba483e94c1e17adf850 = L.map(
#                 &quot;map_9db21f59cc231ba483e94c1e17adf850&quot;,
#                 {
#                     center: [10.7769, 106.7009],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f04080e8cff379330775dc38a008086 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f04080e8cff379330775dc38a008086.addTo(map_9db21f59cc231ba483e94c1e17adf850);
#
#
#             var marker_97369dda8a159b0abd189a5cba76bd37 = L.marker(
#                 [10.77, 106.71],
#                 {
# }
#             ).addTo(map_9db21f59cc231ba483e94c1e17adf850);
#
#
#             var icon_4d11e90ca0776b2140de99d3176e1259 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;user&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3cc612b1d939872044590623163df315 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4eb12b66ac37433c91802849b0d397ec = $(`&lt;div id=&quot;html_4eb12b66ac37433c91802849b0d397ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Khách hàng&lt;/div&gt;`)[0];
#                 popup_3cc612b1d939872044590623163df315.setContent(html_4eb12b66ac37433c91802849b0d397ec);
#
#
#
#         marker_97369dda8a159b0abd189a5cba76bd37.bindPopup(popup_3cc612b1d939872044590623163df315)
#         ;
#
#
#
#
#                 marker_97369dda8a159b0abd189a5cba76bd37.setIcon(icon_4d11e90ca0776b2140de99d3176e1259);
#
#
#             var marker_65af1bcc2b8f7328dd416ad034226e4e = L.marker(
#                 [10.78, 106.69],
#                 {
# }
#             ).addTo(map_9db21f59cc231ba483e94c1e17adf850);
#
#
#             var icon_c01bd21bc4022a7485ba3aa918f5b8c7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_355168a365fd4a21f973192a1e997c28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_361d026991ac5a419a9a2cff1ee41ab2 = $(`&lt;div id=&quot;html_361d026991ac5a419a9a2cff1ee41ab2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Xe công nghệ&lt;/div&gt;`)[0];
#                 popup_355168a365fd4a21f973192a1e997c28.setContent(html_361d026991ac5a419a9a2cff1ee41ab2);
#
#
#
#         marker_65af1bcc2b8f7328dd416ad034226e4e.bindPopup(popup_355168a365fd4a21f973192a1e997c28)
#         ;
#
#
#
#
#                 marker_65af1bcc2b8f7328dd416ad034226e4e.setIcon(icon_c01bd21bc4022a7485ba3aa918f5b8c7);
#
#
#             var poly_line_1eafa496b30e9c0b0b43815b6a854ec3 = L.polyline(
#                 [[10.7802238, 106.6895501], [10.7814155, 106.6907327], [10.7825068, 106.6918155], [10.7814734, 106.6929429], [10.7805422, 106.6939507], [10.7795752, 106.6949909], [10.7805243, 106.6958645], [10.7817005, 106.6969717], [10.782881, 106.6981158], [10.782134, 106.6989238], [10.7815337, 106.6995731], [10.7814762, 106.6996356], [10.7820025, 106.7001223], [10.7823516, 106.7004492], [10.7827374, 106.700811], [10.7827922, 106.7008622], [10.7831604, 106.7012045], [10.7851309, 106.7030685], [10.7846363, 106.7035969], [10.78441, 106.7038502], [10.7836471, 106.7046735], [10.7804052, 106.7085053], [10.7778306, 106.7132012], [10.7773895, 106.7139993], [10.7773394, 106.714089], [10.7772884, 106.7141836], [10.7772382, 106.7142784], [10.7767013, 106.7152493], [10.7762569, 106.7160687], [10.7757469, 106.7169999], [10.7751261, 106.7167289], [10.7714998, 106.7167849], [10.770438, 106.7103898]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noCl

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import folium
np.random.seed(42)
n_customers = 100
data = {
    'lat': np.random.uniform(10.75, 10.85, n_customers),
    'lon': np.random.uniform(106.6, 106.75, n_customers)
}
df = pd.DataFrame(data)
n_clusters = 5
kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(df[['lat', 'lon']])
centroids = kmeans.cluster_centers_
m = folium.Map(location=[10.8, 106.67], zoom_start=12)
for idx, row in df.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius=3,
        color='blue',
        fill=True,
        fill_opacity=0.6
    ).add_to(m)
for i, coord in enumerate(centroids):
    folium.Marker(
        location=[coord[0], coord[1]],
        popup=f"Trạm/Kho hàng {i+1} (Tối ưu)",
        icon=folium.Icon(color='red', icon='star')
    ).add_to(m)
print("Đã tạo bản đồ trực quan hóa vị trí tối ưu!")
m
# Out:
# Đã tạo bản đồ trực quan hóa vị trí tối ưu!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5460ee584f5ff5c8745fcce16e6a15ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5460ee584f5ff5c8745fcce16e6a15ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5460ee584f5ff5c8745fcce16e6a15ae = L.map(
#                 &quot;map_5460ee584f5ff5c8745fcce16e6a15ae&quot;,
#                 {
#                     center: [10.8, 106.67],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42e61db14b16b7a59c248deca3375efa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_42e61db14b16b7a59c248deca3375efa.addTo(map_5460ee584f5ff5c8745fcce16e6a15ae);
#
#
#             var circle_marker_dd601515cf0ffc5c03ae66d89f39d065 = L.circleMarker(
#                 [10.787454011884735, 106.604714377853],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5460ee584f5ff5c8745fcce16e6a15ae);
#
#
#             var circle_marker_096eace28b8bf06fbab0a236bfe55ef3 = L.circleMarker(
#                 [10.845071430640992, 106.69546156168957],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5460ee584f5ff5c8745fcce16e6a15ae);
#
#
#             var circle_marker_a8964d23166665a2c88ba89a815b4f1a = L.circleMarker(
#                 [10.82319939418114, 106.64715339716145],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5460ee584f5ff5c8745fcce16e6a15ae);
#
#
#             var circle_marker_015d8dc70d8c501e66963544f941d892 = L.circleMarker(
#                 [10.809865848419703, 106.6762856036747],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5460ee584f5ff5c8745fcce16e6a15ae);
#
#
#             var circle_marker_dca0bd324b298ba0b8873a1b628bc6a6 = L.circleMarker(
#                 [10.765601864044244, 106.73613497108892],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5460ee584f5ff5c8745fcce16e6a15ae);
#
#
#             var circle_marker_b21a7a16fdc919f4a4d6da48a04671db = L.circleMarker(
#                 [10.76559945203362, 106.63739383437233],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&qu

# %%
import folium
from folium import plugins
data_roads = [
    {"coords": [[10.762, 106.682], [10.772, 106.692]], "name": "Đường A", "density": 0.9, "speed": 10}, # Nguy cơ cao
    {"coords": [[10.772, 106.692], [10.782, 106.702]], "name": "Đường B", "density": 0.3, "speed": 45}, # Nguy cơ thấp
    {"coords": [[10.762, 106.682], [10.752, 106.672]], "name": "Đường C (Dự phòng)", "density": 0.2, "speed": 50}
]
def calculate_risk(density, speed):
    """Hàm logic mờ đơn giản hóa để xác định nguy cơ"""
    if density > 0.7 and speed < 20:
        return "High", "red"
    elif density > 0.4 or speed < 35:
        return "Medium", "orange"
    else:
        return "Low", "green"
m = folium.Map(location=[10.7626, 106.6844], zoom_start=14)
for road in data_roads:
    risk_level, color = calculate_risk(road['density'], road['speed'])
    folium.PolyLine(
        locations=road['coords'],
        color=color,
        weight=8,
        opacity=0.8,
        tooltip=f"{road['name']} - Nguy cơ: {risk_level}"
    ).add_to(m)
    if risk_level == "High":
        alt_road = data_roads[2]
        folium.PolyLine(
            locations=alt_road['coords'],
            color='blue',
            weight=5,
            dash_array='10',
            tooltip="Tuyến đường thay thế đề xuất"
        ).add_to(m)

        folium.Marker(
            location=alt_road['coords'][0],
            icon=folium.Icon(color='blue', icon='info-sign'),
            popup="Lối rẽ gợi ý để tránh tắc nghẽn"
        ).add_to(m)
print("Bản đồ phân tích nguy cơ đã được tạo!")
m
# Out:
# Bản đồ phân tích nguy cơ đã được tạo!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a802281bb46c731a1d7cfb46775edd63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a802281bb46c731a1d7cfb46775edd63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a802281bb46c731a1d7cfb46775edd63 = L.map(
#                 &quot;map_a802281bb46c731a1d7cfb46775edd63&quot;,
#                 {
#                     center: [10.7626, 106.6844],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e09497116c66f76357af09e8cc259554 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e09497116c66f76357af09e8cc259554.addTo(map_a802281bb46c731a1d7cfb46775edd63);
#
#
#             var poly_line_09cba0ac6cbbd0d274762479534c0ef5 = L.polyline(
#                 [[10.762, 106.682], [10.772, 106.692]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_a802281bb46c731a1d7cfb46775edd63);
#
#
#             poly_line_09cba0ac6cbbd0d274762479534c0ef5.bindTooltip(
#                 `&lt;div&gt;
#                      Đường A - Nguy cơ: High
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_c861733194a505424451829030902a10 = L.polyline(
#                 [[10.762, 106.682], [10.752, 106.672]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_a802281bb46c731a1d7cfb46775edd63);
#
#
#             poly_line_c861733194a505424451829030902a10.bindTooltip(
#                 `&lt;div&gt;
#                      Tuyến đường thay thế đề xuất
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_79f253b18c96d4632031f412b422ea06 = L.marker(
#                 [10.762, 106.682],
#                 {
# }
#             ).addTo(map_a802281bb46c731a1d7cfb46775edd63);
#
#
#             var icon_4081d0aff68af8ed81f621f7f3488154 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e492256d4436674a998bc1fa39fd9a3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_586c11fdc28fbcaba37ca7fe78ca9861 = $(`&lt;div id=&quot;html_586c11fdc28fbcaba37ca7fe78ca9861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lối rẽ gợi ý để tránh tắc nghẽn&lt;/div&gt;`)[0];
#                 popup_e492256d4436674a998bc1fa39fd9a3b.setContent(html_586c11fdc28fbcaba37ca7fe78ca9861);
#
#
#
#         marker_79f253b18c96d4632031f412b422ea06.bindPopup(popup_e492256d4436674a998bc1fa39fd9a3b)
#         ;
#
#
#
#
#                 marker_79f253b18c96d4632031f412b422ea06.setIcon(icon_4081d0aff68af8ed81f621f7f3488154);
#
#
#             var poly_line_328a09908396ca8cbc7df815877c3caf = L.polyline(
#                 [[10.772, 106.692], [10.782, 106.702]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_a

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import folium
from folium.plugins import HeatMap
data = pd.DataFrame({
    'zone_id': np.repeat(range(5), 10),
    'hour': np.tile(range(10), 5),
    'demand': np.random.poisson(lam=20, size=50)
})
X = data[['zone_id', 'hour']]
y = data['demand']
model = RandomForestRegressor(n_estimators=100).fit(X, y)
zones_coords = {
    0: [10.77, 106.69], 1: [10.78, 106.70], 2: [10.76, 106.68],
    3: [10.75, 106.67], 4: [10.79, 106.71]
}
predict_data = pd.DataFrame({'zone_id': range(5), 'hour': 11})
predictions = model.predict(predict_data)
m = folium.Map(location=[10.77, 106.69], zoom_start=13)
heat_data = [[zones_coords[i][0], zones_coords[i][1], predictions[i]] for i in range(5)]
HeatMap(heat_data, radius=25).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dbb584ae4a0130d9133645b3e8f884ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dbb584ae4a0130d9133645b3e8f884ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dbb584ae4a0130d9133645b3e8f884ad = L.map(
#                 &quot;map_dbb584ae4a0130d9133645b3e8f884ad&quot;,
#                 {
#                     center: [10.77, 106.69],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4f3717a0c64fe3a3b41fa085e07f263 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4f3717a0c64fe3a3b41fa085e07f263.addTo(map_dbb584ae4a0130d9133645b3e8f884ad);
#
#
#             var heat_map_b3d351ae9c7b77e0daeb0bb5e710bc4f = L.heatLayer(
#                 [[10.77, 106.69, 15.72], [10.78, 106.7, 21.41], [10.76, 106.68, 16.41], [10.75, 106.67, 18.92], [10.79, 106.71, 20.15]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_b3d351ae9c7b77e0daeb0bb5e710bc4f.addTo(map_dbb584ae4a0130d9133645b3e8f884ad);
#
#
#             tile_layer_c4f3717a0c64fe3a3b41fa085e07f263.addTo(map_dbb584ae4a0130d9133645b3e8f884ad);
#
#
#             heat_map_b3d351ae9c7b77e0daeb0bb5e710bc4f.addTo(map_dbb584ae4a0130d9133645b3e8f884ad);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import numpy as np
depot = [10.775, 106.700]
customers = [[10.782, 106.695], [10.770, 106.685], [10.760, 106.710], [10.790, 106.720]]
def euclidean_distance(p1, p2):
    return np.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)
def solve_vrp(start, points):
    route = [start]
    unvisited = points.copy()
    while unvisited:
        nearest = min(unvisited, key=lambda p: euclidean_distance(route[-1], p))
        route.append(nearest)
        unvisited.remove(nearest)
    route.append(start)
    return route
optimized_route = solve_vrp(depot, customers)
m = folium.Map(location=depot, zoom_start=14)
folium.Marker(depot, icon=folium.Icon(color='red', icon='home')).add_to(m)
for c in customers:
    folium.Marker(c, icon=folium.Icon(color='blue')).add_to(m)
folium.PolyLine(optimized_route, color="green", weight=5, opacity=0.7, tooltip="Tuyến tối ưu").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09ff4459c05d0e5a8278563359b01406 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09ff4459c05d0e5a8278563359b01406&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09ff4459c05d0e5a8278563359b01406 = L.map(
#                 &quot;map_09ff4459c05d0e5a8278563359b01406&quot;,
#                 {
#                     center: [10.775, 106.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85a30464c38b57a49a326556c4a1fae1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85a30464c38b57a49a326556c4a1fae1.addTo(map_09ff4459c05d0e5a8278563359b01406);
#
#
#             var marker_3dd6ecf424ad4c1fb4ec521d294c32b5 = L.marker(
#                 [10.775, 106.7],
#                 {
# }
#             ).addTo(map_09ff4459c05d0e5a8278563359b01406);
#
#
#             var icon_fa38b3796aa26b87b6d5bf38bd1cc055 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_3dd6ecf424ad4c1fb4ec521d294c32b5.setIcon(icon_fa38b3796aa26b87b6d5bf38bd1cc055);
#
#
#             var marker_b3b2c049a44c7e374b35a936206dec8c = L.marker(
#                 [10.782, 106.695],
#                 {
# }
#             ).addTo(map_09ff4459c05d0e5a8278563359b01406);
#
#
#             var icon_fe448a5ed283bdc53bd4b6ee2d6e2611 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_b3b2c049a44c7e374b35a936206dec8c.setIcon(icon_fe448a5ed283bdc53bd4b6ee2d6e2611);
#
#
#             var marker_c4c1449753cf30b25f9d8a2532e80094 = L.marker(
#                 [10.77, 106.685],
#                 {
# }
#             ).addTo(map_09ff4459c05d0e5a8278563359b01406);
#
#
#             var icon_88ebe40dabf222af03d2e22315d6a2e5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_c4c1449753cf30b25f9d8a2532e80094.setIcon(icon_88ebe40dabf222af03d2e22315d6a2e5);
#
#
#             var marker_c3276b5e1608b4520db15d6d1a4f5e3f = L.marker(
#                 [10.76, 106.71],
#                 {
# }
#             ).addTo(map_09ff4459c05d0e5a8278563359b01406);
#
#
#             var icon_c651dbb454a8fc013665371a5e54c676 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_c3276b5e1608b4520db15d6d1a4f5e3f.setIcon(icon_c651dbb454a8fc013665371a5e54c676);
#
#
#             var marker_7c43d3a913a3aa801d352ef0cc693c2b = L.marker(
#                 [10.79, 106.72],
#                 {
# }
#             ).addTo(map_09ff4459c05d0e5a8278563359b01406);
#
#
#             var icon_9985d47d99c467992bb8258e7955e2b2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_7c43d3a913a3aa801d352ef0cc693c2b.setIcon(icon_9985d47d99c467992bb8258e7955e2b2);
#
#
#             var poly_line_d010be4d05c21d072fb6fc4aa4a8402e = L.polyline(
#                 [[10.775, 106.7], [10.782, 106.695], [10.77, 106.685], [10.76, 106.71], [10.79, 106.72], [10.775, 106.7]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;ro

# %%
from folium.plugins import TimestampedGeoJson
features = [
    {
        'type': 'Feature',
        'geometry': {
            'type': 'Point',
            'coordinates': [106.682, 10.762], # Kinh độ, Vĩ độ
        },
        'properties': {
            'time': '2023-10-01T08:00:00',
            'popup': 'Xe A: Bắt đầu'
        }
    },
    {
        'type': 'Feature',
        'geometry': {
            'type': 'Point',
            'coordinates': [106.692, 10.772],
        },
        'properties': {
            'time': '2023-10-01T08:15:00',
            'popup': 'Xe A: Đang di chuyển'
        }
    }
]

m = folium.Map(location=[10.762, 106.682], zoom_start=14)
TimestampedGeoJson(
    {'type': 'FeatureCollection', 'features': features},
    period='PT15M',
    add_last_point=True
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8c29e46a48108b028eea4302d2a3c42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8c29e46a48108b028eea4302d2a3c42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8c29e46a48108b028eea4302d2a3c42 = L.map(
#                 &quot;map_c8c29e46a48108b028eea4302d2a3c42&quot;,
#                 {
#                     center: [10.762, 106.682],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b03a462a54bc85718342350b89e0b4b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b03a462a54bc85718342350b89e0b4b4.addTo(map_c8c29e46a48108b028eea4302d2a3c42);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM-DD HH:mm:ss&quot;);
#                 }
#             });
#             map_c8c29e46a48108b028eea4302d2a3c42.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;PT15M&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {
#   &quot;position&quot;: &quot;bottomleft&quot;,
#   &quot;minSpeed&quot;: 0.1,
#   &quot;maxSpeed&quot;: 10,
#   &quot;autoPlay&quot;: true,
#   &quot;loopButton&quot;: false,
#   &quot;timeSliderDragUpdate&quot;: false,
#   &quot;speedSlider&quot;: true,
#   &quot;playerOptions&quot;: {
#   &quot;transitionTime&quot;: 200,
#   &quot;loop&quot;: true,
#   &quot;startOver&quot;: true,
# },
# }
#             );
#             map_c8c29e46a48108b028eea4302d2a3c42.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson({&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [106.682, 10.762]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2023-10-01T08:00:00&quot;, &quot;popup&quot;: &quot;Xe A: B\u1eaft \u0111\u1ea7u&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [106.692, 10.772]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2023-10-01T08:15:00&quot;, &quot;popup&quot;: &quot;Xe A: \u0110ang di chuy\u1ec3n&quot;}}]}, {
#                     pointToLayer: function (feature, latLng) {
#                         if (feature.properties.icon == &#x27;marker&#x27;) {
#                             if(feature.properties.iconstyle){
#                                 return new L.Marker(latLng, {
#                                     icon: L.icon(feature.properties.iconstyle)});
#                             }
#                             //else
#                             return new L.Marker(latLng);
#                         }
#                         if (feature.properties.icon == &#x27;circle&#x27;) {
#                             if (feature.properties.iconstyle) {
#                                 return new L.circleMarker(latLng, feature.properties.iconstyle)
#                                 };
#                             //else
#                             return new L.circleMarker(latLng);
#                         }
#                         //else
#
#                         return new L.Marker(latLng);
#                     },
#                     style: function (feature) {
#                         return feature.properties.style;
#                     },
#                     onEachFeature: function(feature, layer) {

# %%
import folium
import pandas as pd
from folium.plugins import MarkerCluster

data = pd.DataFrame({
    "lat": [10.76, 10.78, 10.75, 10.77],
    "lon": [106.66, 106.68, 106.64, 106.67],
    "order_id": ["A01", "A02", "A03", "A04"],
    "status": ["Đã giao", "Chưa giao", "Đang giao", "Đã giao"]})
m = folium.Map(location=[10.76, 106.66], zoom_start=13)
marker_cluster = MarkerCluster().add_to(m)
for _, row in data.iterrows():
    color = {
        "Đã giao": "green",
        "Chưa giao": "red",
        "Đang giao": "orange"
    }[row["status"]]
    folium.Marker(
        location=[row["lat"], row["lon"]],
        popup=f"""
        <b>Đơn hàng:</b> {row['order_id']}<br>
        <b>Trạng thái:</b> {row['status']}
        """,
        icon=folium.Icon(color=color)).add_to(marker_cluster)

folium.Polygon(
    locations=[
        [10.75, 106.64],
        [10.79, 106.64],
        [10.79, 106.69],
        [10.75, 106.69]],
    color="blue",
    fill=True,
    fill_opacity=0.2,
    popup="Khu vực trung tâm"
).add_to(m)
route = [
    [10.76, 106.66],
    [10.78, 106.68],
    [10.75, 106.64],
    [10.77, 106.67]
]
folium.PolyLine(
    route,
    color="purple",
    weight=4,
    tooltip="Tuyến giao hàng"
).add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f26cd7b5386d04b09713bbcbf8e04db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f26cd7b5386d04b09713bbcbf8e04db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f26cd7b5386d04b09713bbcbf8e04db = L.map(
#                 &quot;map_5f26cd7b5386d04b09713bbcbf8e04db&quot;,
#                 {
#                     center: [10.76, 106.66],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32c3c29ef31ab6feac7a2795551c4466 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_32c3c29ef31ab6feac7a2795551c4466.addTo(map_5f26cd7b5386d04b09713bbcbf8e04db);
#
#
#             var marker_cluster_1f403228f237daeef99e2d2551f4161f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_6a3bf9efeadac11c25565d8b6fa856e2 = L.marker(
#                 [10.76, 106.66],
#                 {
# }
#             ).addTo(marker_cluster_1f403228f237daeef99e2d2551f4161f);
#
#
#             var icon_e8d6e615385fcd27babde56e049c29c1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_980fd4307db9149b299c376ebbc187b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_981bcf261154abbef3102e06fbb986b7 = $(`&lt;div id=&quot;html_981bcf261154abbef3102e06fbb986b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Đơn hàng:&lt;/b&gt; A01&lt;br&gt;         &lt;b&gt;Trạng thái:&lt;/b&gt; Đã giao         &lt;/div&gt;`)[0];
#                 popup_980fd4307db9149b299c376ebbc187b0.setContent(html_981bcf261154abbef3102e06fbb986b7);
#
#
#
#         marker_6a3bf9efeadac11c25565d8b6fa856e2.bindPopup(popup_980fd4307db9149b299c376ebbc187b0)
#         ;
#
#
#
#
#                 marker_6a3bf9efeadac11c25565d8b6fa856e2.setIcon(icon_e8d6e615385fcd27babde56e049c29c1);
#
#
#             var marker_0f5e822ba1d6a32ce6761cfdc1574842 = L.marker(
#                 [10.78, 106.68],
#                 {
# }
#             ).addTo(marker_cluster_1f403228f237daeef99e2d2551f4161f);
#
#
#             var icon_918a4245f00e6378acbed0aaf66a9249 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_750b817d9706d89fcf42cef5393144b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_881cb6792150d84ba4da2d93a5127bbe = $(`&lt;div id=&quot;html_881cb6792150d84ba4da2d93a5127bbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Đơn hàng:&lt;/b&gt; A02&lt;br&gt;         &lt;b&gt;Trạng thái:&lt;/b&gt; Chưa giao         &lt;/div&gt;`)[0];
#                 popup_750b817d9706d89fcf42cef5393144b5.setContent(html_881cb6792150d84ba4da2d93a5127bbe);
#
#
#
#         marker_0f5e822ba1d6a32ce6761cfdc1574842.bindPopup(popup_750b817d9706d89fcf42cef5393144b5)
#         ;
#
#
#
#
#                 marker_0f5e822ba1d6a32ce6761cfdc1574842.setIcon(icon_918a4245f00e6378acbed0aaf66a9249);
#
#
#             var marker_6e02d4f79416931f6c3c3b2cab882cb4 = L.marker(
#                 [10.75, 106.64],
#                 {
# }
#             ).addTo(marker_cluster_1f403228f237daeef99e2d2551f4161f);
#
#
#             var icon_bdbe73c9462d2803a885b23a7960f97d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );

# %%
import folium
from folium.plugins import TimestampedGeoJson
m = folium.Map(location=[10.7626, 106.6601], zoom_start=13)
truck_movement = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "geometry": {"type": "Point", "coordinates": [106.660, 10.762]},
            "properties": {"time": "2024-01-01T08:00:00", "popup": "Trạng thái: Đang lấy hàng"}
        },
        {
            "type": "Feature",
            "geometry": {"type": "Point", "coordinates": [106.665, 10.765]},
            "properties": {"time": "2024-01-01T08:10:00", "popup": "Trạng thái: Đang di chuyển"}
        },
        {
            "type": "Feature",
            "geometry": {"type": "Point", "coordinates": [106.670, 10.768]},
            "properties": {"time": "2024-01-01T08:20:00", "popup": "Trạng thái: Đã đến nơi"}
        }
    ]
}

TimestampedGeoJson(
    truck_movement,
    period="PT10M",
    add_last_point=True,
    auto_play=True,
    loop=True,
    max_speed=2
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c30e128e9a185ed1e9e5c6cae32e043d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c30e128e9a185ed1e9e5c6cae32e043d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c30e128e9a185ed1e9e5c6cae32e043d = L.map(
#                 &quot;map_c30e128e9a185ed1e9e5c6cae32e043d&quot;,
#                 {
#                     center: [10.7626, 106.6601],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2fc094e16f186640cc080b94cf32384 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2fc094e16f186640cc080b94cf32384.addTo(map_c30e128e9a185ed1e9e5c6cae32e043d);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM-DD HH:mm:ss&quot;);
#                 }
#             });
#             map_c30e128e9a185ed1e9e5c6cae32e043d.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;PT10M&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {
#   &quot;position&quot;: &quot;bottomleft&quot;,
#   &quot;minSpeed&quot;: 0.1,
#   &quot;maxSpeed&quot;: 2,
#   &quot;autoPlay&quot;: true,
#   &quot;loopButton&quot;: false,
#   &quot;timeSliderDragUpdate&quot;: false,
#   &quot;speedSlider&quot;: true,
#   &quot;playerOptions&quot;: {
#   &quot;transitionTime&quot;: 200,
#   &quot;loop&quot;: true,
#   &quot;startOver&quot;: true,
# },
# }
#             );
#             map_c30e128e9a185ed1e9e5c6cae32e043d.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson({&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [106.66, 10.762]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-01-01T08:00:00&quot;, &quot;popup&quot;: &quot;Tr\u1ea1ng th\u00e1i: \u0110ang l\u1ea5y h\u00e0ng&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [106.665, 10.765]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-01-01T08:10:00&quot;, &quot;popup&quot;: &quot;Tr\u1ea1ng th\u00e1i: \u0110ang di chuy\u1ec3n&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [106.67, 10.768]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-01-01T08:20:00&quot;, &quot;popup&quot;: &quot;Tr\u1ea1ng th\u00e1i: \u0110\u00e3 \u0111\u1ebfn n\u01a1i&quot;}}]}, {
#                     pointToLayer: function (feature, latLng) {
#                         if (feature.properties.icon == &#x27;marker&#x27;) {
#                             if(feature.properties.iconstyle){
#                                 return new L.Marker(latLng, {
#                                     icon: L.icon(feature.properties.iconstyle)});
#                             }
#                             //else
#                             return new L.Marker(latLng);
#                         }
#                         if (feature.properties.icon == &#x27;circle&#x27;) {
#                             if (feature.properties.iconstyle) {
#                                 return new L.circleMarker(latLng, feature.properties.iconstyle)
#                                 };
#                             //else
#                             return new L.circ
